# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sklearn.datasets

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
titanic = sns.load_dataset('titanic')

# %%
class KNN():
    
    def __init(self):
        self.K = None
        self.X_train = None
        self.y_train = None
        self.vizinhos_index = None
        
    def fit(self, X_train, y_train):
        self.X_train = X_train
        self.y_train = y_train
        
    def predict(self, X, K=1):
        self.K = K
        classes = np.unique(self.y_train)
        y_pred = []
        dist_total = []
        self.vizinhos_index = []

        for xi in X:
            euclidistancias = -2 * xi @ self.X_train.T + (xi**2).sum() + (self.X_train**2).sum(axis=1)
            
            
            knn_index = np.argsort(euclidistancias)[0:K]
            self.vizinhos_index.append(knn_index)
            contagem = []
            dist_total = []
            
            for classe in classes:
                contagem.append((self.y_train[knn_index]==classe).sum())
                dist_classe = np.sum(euclidistancias[knn_index][self.y_train[knn_index]==classe])
                dist_total.append(dist_classe)
                
            contagem = np.array(contagem)
            
            #criar lista de classes empatadas
            indice_classes_empatadas = []
            for i in range(len(contagem)):
                if contagem[i] == max(contagem):
                    indice_classes_empatadas.append(i)
            
            # Popular y_pred com as duas regras de decisão: 
                # Se não empate: classe com maior votação
                # Se empate: classe com menor distância entre as classes empatadas
            
            dist_total = np.array(dist_total)

            if len(indice_classes_empatadas) == 1:
                pred_index = np.argmax(contagem)
                y_pred.append(classes[pred_index])
                
                
    
            else:
                # menor valor das distancias totais que estão com a mesma quantidade de votos
                menor_valor = np.min(dist_total[indice_classes_empatadas])
                
                # indice da menor distancia contando todas as distâncias
                indice_menor_dist = np.where(dist_total == menor_valor)[0][0]
                
                # Predição pra essa instância = Classe que tem a menor distancia
                y_pred.append(classes[indice_menor_dist])
            

            
        return np.array(y_pred)

# %%
from sklearn.datasets import load_breast_cancer
X, y = load_breast_cancer(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=13)

# %%
knn = KNN()

# %%
knn.fit(X_train, y_train)

# %%
y_pred = knn.predict(X_test, 4)

# %%
knn.vizinhos_index
# Out:
# [array([381, 419, 107, 355], dtype=int64),
#  array([ 58, 352,  14, 153], dtype=int64),
#  array([ 99,  36, 132, 151], dtype=int64),
#  array([282, 313,  94, 381], dtype=int64),
#  array([330, 347, 152, 151], dtype=int64),
#  array([159, 337, 110, 138], dtype=int64),
#  array([ 42, 107, 419, 380], dtype=int64),
#  array([400, 399, 176, 265], dtype=int64),
#  array([281, 339, 133,  60], dtype=int64),
#  array([101, 361,  41, 229], dtype=int64),
#  array([130, 406, 391, 232], dtype=int64),
#  array([397, 233,  27, 192], dtype=int64),
#  array([378, 383,   0, 393], dtype=int64),
#  array([158, 403, 410, 111], dtype=int64),
#  array([194, 395, 353, 189], dtype=int64),
#  array([314, 160, 125,  38], dtype=int64),
#  array([163, 417, 186, 335], dtype=int64),
#  array([329, 314, 160, 352], dtype=int64),
#  array([372,  60, 339, 119], dtype=int64),
#  array([111, 124, 316, 158], dtype=int64),
#  array([ 16,  38, 272,  34], dtype=int64),
#  array([282, 313,  94, 381], dtype=int64),
#  array([128, 273,  45, 209], dtype=int64),
#  array([269, 332, 115,  10], dtype=int64),
#  array([115, 332, 269,  57], dtype=int64),
#  array([381, 355, 416, 313], dtype=int64),
#  array([237, 201,  66, 290], dtype=int64),
#  array([164, 136, 371, 203], dtype=int64),
#  array([281, 374, 339, 133], dtype=int64),
#  array([357, 368,  84,  98], dtype=int64),
#  array([128,  51, 273, 209], dtype=int64),
#  array([266, 408, 188, 240], dtype=int64),
#  array([ 38, 272,  16, 234], dtype=int64),
#  array([352, 153,  14,  72], dtype=int64),
#  array([118, 303, 250, 225], dtype=int64),
#  array([341, 231, 226,  45], dtype=int64),
#  array([267,  74,  55, 131], dtype=int64),
#  array([178, 254, 104, 187], dtype=int64),
#  array([273, 263, 218,  63], dtype=int64),
#  array([209,  87, 398, 298], dtype=int64),
#  array([416,  12, 381, 107], dtype=int64),
#  array([319, 276,  84,  50], dtype=int64),
#  array([ 60, 302, 372, 332], dtype=int64),
#  array([264, 306, 269, 113], dtype=int64),
#  array([423, 331,  82, 271], dtype=int64),
#  array([333, 103, 147, 399], dtype=int64),
#  array([425, 354, 292,  44], dtype=int64),
#  array([337, 159, 110, 138], dtype=int64),
#  array([128,  45, 273, 231], dtype=int64),
#  array([261, 179,  25, 279], dtype=int64),
#  array([227, 305,  28,  76], dtype=int64),
#  array([ 15,  77, 191,   8], dtype=int64),
#  array([181, 198,  39,  20], dtype=int64),
#  array([  2, 167, 239, 210], dtype=int64),
#  array([423,  82, 331, 244], dtype=int64),
#  array([319,  84, 276, 357], dtype=int64),
#  array([205, 133, 306,  83], dtype=int64),
#  array([ 20, 198, 195,  39], dtype=int64),
#  array([ 85, 140, 197, 123], dtype=int64),
#  array([260, 252, 328, 383], dtype=int64),
#  array([ 64, 157, 177, 172], dtype=int64),
#  array([271, 244,  34,  16], dtype=int64),
#  array([284,  94, 165, 343], dtype=int64),
#  array([ 29, 162,  52, 248], dtype=int64),
#  array([ 25, 261,  69, 238], dtype=int64),
#  array([163, 186, 417, 262], dtype=int64),
#  array([390, 323, 343, 134], dtype=int64),
#  array([ 72, 415, 394,  14], dtype=int64),
#  array([210, 167,   2, 220], dtype=int64),
#  array([ 91, 139, 207, 211], dtype=int64),
#  array([ 56, 338,  62, 385], dtype=int64),
#  array([101, 300, 263, 364], dtype=int64),
#  array([270, 168, 315,  17], dtype=int64),
#  array([348,  40,  64,  11], dtype=int64),
#  array([ 50, 195, 319, 276], dtype=int64),
#  array([331, 423,  82, 244], dtype=int64),
#  array([410, 403, 256, 181], dtype=int64),
#  array([  7, 200,  53, 280], dtype=int64),
#  array([425, 220,  78, 354], dtype=int64),
#  array([338, 385,  62,  92], dtype=int64),
#  array([219, 260, 349, 397], dtype=int64),
#  array([ 99,  81, 138, 242], dtype=int64),
#  array([ 12, 390, 134, 370], dtype=int64),
#  array([280,   7,  53, 179], dtype=int64),
#  array([ 83, 169, 180, 318], dtype=int64),
#  array([118, 250, 303, 225], dtype=int64),
#  array([195,  20, 198, 225], dtype=int64),
#  array([289, 207,  11, 211], dtype=int64),
#  array([399, 333, 275, 350], dtype=int64),
#  array([200,  53,   7, 322], dtype=int64),
#  array([ 13, 393, 224, 275], dtype=int64),
#  array([392, 121,  76, 344], dtype=int64),
#  array([176, 265,  86,  24], dtype=int64),
#  array([  4, 391, 130,  35], dtype=int64),
#  array([281, 339, 133, 374], dtype=int64),
#  array([ 33, 362,  43, 200], dtype=int64),
#  array([151,  36, 347, 421], dtype=int64),
#  array([244, 271,  34,  16], dtype=int64),
#  array([243, 364, 143,  63], dtype=int64),
#  array([145, 401,  28,  76], dtype=int64),
#  array([154, 264, 394,  14], dtype=int64),
#  array([380, 156,  42, 135], dtype=int64),
#  array([365, 187, 132, 387], dtype=int64),
#  array([254, 104, 421, 187], dtype=int64),
#  array([327,  74, 359,  94], dtype=int64),
#  array([ 94, 255, 193, 284], dtype=int64),
#  array([157,  64, 172, 177], dtype=int64),
#  array([ 61,   5, 123, 202], dtype=int64),
#  array([266, 240, 408, 188], dtype=int64),
#  array([209, 128, 298,  51], dtype=int64),
#  array([402, 370, 117, 116], dtype=int64),
#  array([248, 367, 356,  29], dtype=int64),
#  array([380,  31, 345, 202], dtype=int64),
#  array([331, 423, 271,  82], dtype=int64),
#  array([ 28,  76, 227, 344], dtype=int64),
#  array([239,  97,  80, 167], dtype=int64),
#  array([420, 276, 319,  65], dtype=int64),
#  array([330, 347,  18, 369], dtype=int64),
#  array([192,  93,  18,  75], dtype=int64),
#  array([206,   9,  47, 292], dtype=int64),
#  array([298, 371, 164,  87], dtype=int64),
#  array([119,   0, 339, 142], dtype=int64),
#  array([ 19, 127, 288, 305], dtype=int64),
#  array([ 41, 229, 317, 361], dtype=int64),
#  array([339, 374,  60, 302], dtype=int64),
#  array([305, 227, 127, 288], dtype=int64),
#  array([340, 220,  78, 315], dtype=int64),
#  array([344, 102,  76, 392], dtype=int64),
#  array([196, 277, 289, 135], dtype=int64),
#  array([279, 409, 322, 179], dtype=int64),
#  array([ 89,  83, 109, 257], dtype=int64),
#  array([ 72, 415,  14, 394], dtype=int64),
#  array([ 15,   8,  77, 108], dtype=int64),
#  array([179,  25, 261,  53], dtype=int64),
#  array([ 77, 403, 108, 171], dtype=int64),
#  array([102, 344,  76,  65], dtype=int64),
#  array([ 12, 416, 134, 323], dtype=int64),
#  array([ 79, 411, 379, 404], dtype=int64),
#  array([395,  31, 353, 194], dtype=int64),
#  array([ 21, 307, 420,  50], dtype=int64),
#  array([170, 424, 413, 377], dtype=int64),
#  array([415,  72, 394,  10], dtype=int64),
#  array([145, 401,  65, 420], dtype=int64)]

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.916083916083916

# %%
# Modelo com código procedural

K = 4
classes = np.unique(y_train)
y_pred = []
vizinhos_index = []
        
for xi in X_test:
    euclidistancias = -2 * xi @ X_train.T + (xi**2).sum() + (X_train**2).sum(axis=1)
            
    knn_index = np.argsort(euclidistancias)[0:K]
    vizinhos_index.append(knn_index)
    
    contagem = []
    dist_total = []
    
    for classe in classes:
        contagem.append((y_train[knn_index]==classe).sum())
        dist_classe = np.sum(euclidistancias[knn_index][y_train[knn_index]==classe])
        dist_total.append(dist_classe)
    
    contagem = np.array(contagem)
    
    #criar lista de classes empatadas
    indice_classes_empatadas = []
    for i in range(len(contagem)):
        if contagem[i] == max(contagem):
            indice_classes_empatadas.append(i)
      
    # Popular y_pred com as duas regras de decisão: 
        # Se não empate: classe com maior votação
        # Se empate: classe com menor distância entre as classes empatadas
    
    dist_total = np.array(dist_total)
    
    if len(indice_classes_empatadas) == 1:
        pred_index = np.argmax(contagem)
        y_pred.append(classes[pred_index])
    
    else:
        # menor valor das distancias totais que estão com a mesma quantidade de votos
        menor_valor = np.min(dist_total[indice_classes_empatadas])

        # indice da menor distancia contando todas as distâncias
        indice_menor_dist = np.where(dist_total == menor_valor)[0][0]

        # Classe que tem a menor distancia
        y_pred.append(classes[indice_menor_dist])
        
        #bloco de teste
        print("----------------------------Check de sanidade para instâncias com empate-----------------------------")

        print("contagem: ")
        print(contagem)
        print("dist_total: ")
        print(dist_total)
        print("menor_valor: ")
        print(menor_valor)
        print("indice_menor_dist: ")
        print(indice_menor_dist)
        
        
            
y_pred = np.array(y_pred)
# Out:
# ----------------------------Check de sanidade para instâncias com empate-----------------------------
# contagem:
# [2 2]
# dist_total:
# [ 719.56582745 3255.53119999]
# menor_valor:
# 719.5658274518792
# indice_menor_dist:
# 0
# ----------------------------Check de sanidade para instâncias com empate-----------------------------
# contagem:
# [2 2]
# dist_total:
# [1268.75277352 1094.83786102]
# menor_valor:
# 1094.837861015927
# indice_menor_dist:
# 1
# ----------------------------Check de sanidade para instâncias com empate-----------------------------
# contagem:
# [2 2]
# dist_total:
# [1576.64861988 2072.00281733]
# menor_valor:
# 1576.648619877873
# indice_menor_dist:
# 0
# ----------------------------Check de sanidade para instâncias com empate-----------------------------
# contagem:
# [2 2]
# dist_total:
# [4066.93041466 4423.56557632]
# menor_valor:
# 4066.93041465641
# indice_menor_dist:
# 0
# ----------------------------Check de sanidade para instâncias com empate-----------------------------
# contagem:
# [2 2]
# dist_total:
# [4400.16051919 4066.03203922]
# menor_valor:
# 4066.0320392209105
# indice_menor_dist:
# 1
# ----------------------------Check de sanidade para instâncias com empate-----------------------------
# contagem:
# [2 2]
# dist_total:
# [1907.72793221 3082.68220719]
# menor_valor:
# 1907.7279322098475
# indice_menor_dist:
# 0

# %%
(y_train[knn_index]==classe)
# Out:
# array([False, False, False, False])

# %%
((y_train[knn_index]==classe).sum())
# Out:
# 0

# %%
vizinhos_index
# Out:
# [array([381, 419, 107, 355], dtype=int64),
#  array([ 58, 352,  14, 153], dtype=int64),
#  array([ 99,  36, 132, 151], dtype=int64),
#  array([282, 313,  94, 381], dtype=int64),
#  array([330, 347, 152, 151], dtype=int64),
#  array([159, 337, 110, 138], dtype=int64),
#  array([ 42, 107, 419, 380], dtype=int64),
#  array([400, 399, 176, 265], dtype=int64),
#  array([281, 339, 133,  60], dtype=int64),
#  array([101, 361,  41, 229], dtype=int64),
#  array([130, 406, 391, 232], dtype=int64),
#  array([397, 233,  27, 192], dtype=int64),
#  array([378, 383,   0, 393], dtype=int64),
#  array([158, 403, 410, 111], dtype=int64),
#  array([194, 395, 353, 189], dtype=int64),
#  array([314, 160, 125,  38], dtype=int64),
#  array([163, 417, 186, 335], dtype=int64),
#  array([329, 314, 160, 352], dtype=int64),
#  array([372,  60, 339, 119], dtype=int64),
#  array([111, 124, 316, 158], dtype=int64),
#  array([ 16,  38, 272,  34], dtype=int64),
#  array([282, 313,  94, 381], dtype=int64),
#  array([128, 273,  45, 209], dtype=int64),
#  array([269, 332, 115,  10], dtype=int64),
#  array([115, 332, 269,  57], dtype=int64),
#  array([381, 355, 416, 313], dtype=int64),
#  array([237, 201,  66, 290], dtype=int64),
#  array([164, 136, 371, 203], dtype=int64),
#  array([281, 374, 339, 133], dtype=int64),
#  array([357, 368,  84,  98], dtype=int64),
#  array([128,  51, 273, 209], dtype=int64),
#  array([266, 408, 188, 240], dtype=int64),
#  array([ 38, 272,  16, 234], dtype=int64),
#  array([352, 153,  14,  72], dtype=int64),
#  array([118, 303, 250, 225], dtype=int64),
#  array([341, 231, 226,  45], dtype=int64),
#  array([267,  74,  55, 131], dtype=int64),
#  array([178, 254, 104, 187], dtype=int64),
#  array([273, 263, 218,  63], dtype=int64),
#  array([209,  87, 398, 298], dtype=int64),
#  array([416,  12, 381, 107], dtype=int64),
#  array([319, 276,  84,  50], dtype=int64),
#  array([ 60, 302, 372, 332], dtype=int64),
#  array([264, 306, 269, 113], dtype=int64),
#  array([423, 331,  82, 271], dtype=int64),
#  array([333, 103, 147, 399], dtype=int64),
#  array([425, 354, 292,  44], dtype=int64),
#  array([337, 159, 110, 138], dtype=int64),
#  array([128,  45, 273, 231], dtype=int64),
#  array([261, 179,  25, 279], dtype=int64),
#  array([227, 305,  28,  76], dtype=int64),
#  array([ 15,  77, 191,   8], dtype=int64),
#  array([181, 198,  39,  20], dtype=int64),
#  array([  2, 167, 239, 210], dtype=int64),
#  array([423,  82, 331, 244], dtype=int64),
#  array([319,  84, 276, 357], dtype=int64),
#  array([205, 133, 306,  83], dtype=int64),
#  array([ 20, 198, 195,  39], dtype=int64),
#  array([ 85, 140, 197, 123], dtype=int64),
#  array([260, 252, 328, 383], dtype=int64),
#  array([ 64, 157, 177, 172], dtype=int64),
#  array([271, 244,  34,  16], dtype=int64),
#  array([284,  94, 165, 343], dtype=int64),
#  array([ 29, 162,  52, 248], dtype=int64),
#  array([ 25, 261,  69, 238], dtype=int64),
#  array([163, 186, 417, 262], dtype=int64),
#  array([390, 323, 343, 134], dtype=int64),
#  array([ 72, 415, 394,  14], dtype=int64),
#  array([210, 167,   2, 220], dtype=int64),
#  array([ 91, 139, 207, 211], dtype=int64),
#  array([ 56, 338,  62, 385], dtype=int64),
#  array([101, 300, 263, 364], dtype=int64),
#  array([270, 168, 315,  17], dtype=int64),
#  array([348,  40,  64,  11], dtype=int64),
#  array([ 50, 195, 319, 276], dtype=int64),
#  array([331, 423,  82, 244], dtype=int64),
#  array([410, 403, 256, 181], dtype=int64),
#  array([  7, 200,  53, 280], dtype=int64),
#  array([425, 220,  78, 354], dtype=int64),
#  array([338, 385,  62,  92], dtype=int64),
#  array([219, 260, 349, 397], dtype=int64),
#  array([ 99,  81, 138, 242], dtype=int64),
#  array([ 12, 390, 134, 370], dtype=int64),
#  array([280,   7,  53, 179], dtype=int64),
#  array([ 83, 169, 180, 318], dtype=int64),
#  array([118, 250, 303, 225], dtype=int64),
#  array([195,  20, 198, 225], dtype=int64),
#  array([289, 207,  11, 211], dtype=int64),
#  array([399, 333, 275, 350], dtype=int64),
#  array([200,  53,   7, 322], dtype=int64),
#  array([ 13, 393, 224, 275], dtype=int64),
#  array([392, 121,  76, 344], dtype=int64),
#  array([176, 265,  86,  24], dtype=int64),
#  array([  4, 391, 130,  35], dtype=int64),
#  array([281, 339, 133, 374], dtype=int64),
#  array([ 33, 362,  43, 200], dtype=int64),
#  array([151,  36, 347, 421], dtype=int64),
#  array([244, 271,  34,  16], dtype=int64),
#  array([243, 364, 143,  63], dtype=int64),
#  array([145, 401,  28,  76], dtype=int64),
#  array([154, 264, 394,  14], dtype=int64),
#  array([380, 156,  42, 135], dtype=int64),
#  array([365, 187, 132, 387], dtype=int64),
#  array([254, 104, 421, 187], dtype=int64),
#  array([327,  74, 359,  94], dtype=int64),
#  array([ 94, 255, 193, 284], dtype=int64),
#  array([157,  64, 172, 177], dtype=int64),
#  array([ 61,   5, 123, 202], dtype=int64),
#  array([266, 240, 408, 188], dtype=int64),
#  array([209, 128, 298,  51], dtype=int64),
#  array([402, 370, 117, 116], dtype=int64),
#  array([248, 367, 356,  29], dtype=int64),
#  array([380,  31, 345, 202], dtype=int64),
#  array([331, 423, 271,  82], dtype=int64),
#  array([ 28,  76, 227, 344], dtype=int64),
#  array([239,  97,  80, 167], dtype=int64),
#  array([420, 276, 319,  65], dtype=int64),
#  array([330, 347,  18, 369], dtype=int64),
#  array([192,  93,  18,  75], dtype=int64),
#  array([206,   9,  47, 292], dtype=int64),
#  array([298, 371, 164,  87], dtype=int64),
#  array([119,   0, 339, 142], dtype=int64),
#  array([ 19, 127, 288, 305], dtype=int64),
#  array([ 41, 229, 317, 361], dtype=int64),
#  array([339, 374,  60, 302], dtype=int64),
#  array([305, 227, 127, 288], dtype=int64),
#  array([340, 220,  78, 315], dtype=int64),
#  array([344, 102,  76, 392], dtype=int64),
#  array([196, 277, 289, 135], dtype=int64),
#  array([279, 409, 322, 179], dtype=int64),
#  array([ 89,  83, 109, 257], dtype=int64),
#  array([ 72, 415,  14, 394], dtype=int64),
#  array([ 15,   8,  77, 108], dtype=int64),
#  array([179,  25, 261,  53], dtype=int64),
#  array([ 77, 403, 108, 171], dtype=int64),
#  array([102, 344,  76,  65], dtype=int64),
#  array([ 12, 416, 134, 323], dtype=int64),
#  array([ 79, 411, 379, 404], dtype=int64),
#  array([395,  31, 353, 194], dtype=int64),
#  array([ 21, 307, 420,  50], dtype=int64),
#  array([170, 424, 413, 377], dtype=int64),
#  array([415,  72, 394,  10], dtype=int64),
#  array([145, 401,  65, 420], dtype=int64)]

# %%
euclidistancias
# Out:
# array([1.09695151e+06, 1.61592160e+06, 1.56632284e+06, 1.13472053e+06,
#        2.16381161e+06, 5.68793499e+05, 9.06532434e+05, 1.86373346e+06,
#        1.00058391e+05, 1.65954408e+06, 9.74996369e+05, 5.01715281e+05,
#        6.63751510e+05, 1.14678452e+06, 9.36827050e+05, 1.29269955e+05,
#        8.87855507e+05, 1.44676653e+06, 1.28565487e+06, 6.46817384e+04,
#        7.55693004e+04, 4.40708283e+04, 1.35825132e+06, 7.75607640e+05,
#        1.23795470e+06, 1.75434770e+06, 1.69854910e+06, 1.29402784e+06,
#        3.75373690e+04, 1.15645970e+06, 1.47344819e+05, 5.72797927e+05,
#        6.43549419e+05, 1.95541379e+06, 8.99714695e+05, 2.04364349e+06,
#        1.32517536e+06, 6.99185781e+05, 8.76451194e+05, 7.39359221e+04,
#        4.78878727e+05, 4.63349434e+05, 6.08971562e+05, 1.95572370e+06,
#        1.64074006e+06, 3.32130696e+05, 3.32412288e+05, 1.64517409e+06,
#        8.50798129e+05, 7.78533792e+05, 5.01562327e+04, 2.62034655e+05,
#        8.19324318e+05, 1.85072743e+06, 1.59840591e+06, 7.65017760e+05,
#        4.82724787e+06, 9.94694653e+05, 9.24139148e+05, 7.39525097e+05,
#        1.04335385e+06, 5.88951787e+05, 3.47283870e+06, 3.31484778e+05,
#        4.93041390e+05, 9.05970815e+03, 8.72102011e+05, 4.50896722e+06,
#        1.19322077e+05, 1.72736608e+06, 1.77328721e+05, 2.09461685e+05,
#        9.45121373e+05, 1.09836967e+06, 7.84014052e+05, 1.27703380e+06,
#        2.97177722e+04, 1.27520299e+05, 1.54463461e+06, 3.68824774e+05,
#        1.61387631e+06, 1.32296218e+06, 9.86381079e+05, 1.07087520e+06,
#        3.17424874e+04, 4.82284688e+05, 1.24479940e+06, 1.42010113e+05,
#        1.12802157e+06, 1.04441893e+06, 1.16444157e+06, 5.15612995e+05,
#        2.23635000e+06, 1.28189259e+06, 7.34564204e+05, 1.13885992e+05,
#        4.51336339e+05, 1.64968342e+06, 4.40750141e+04, 1.32261736e+06,
#        8.40774638e+05, 4.11185332e+05, 2.24452031e+04, 1.17156827e+06,
#        1.37525465e+06, 1.46379758e+05, 6.42214957e+05, 6.34953339e+05,
#        1.48164287e+05, 1.09711408e+06, 1.27242184e+06, 2.94694981e+05,
#        7.45934161e+05, 1.01964168e+06, 2.08821830e+06, 1.02138698e+06,
#        7.48810653e+05, 7.46027255e+05, 1.37274711e+05, 1.07019808e+06,
#        2.69428893e+05, 4.42172771e+04, 1.20860328e+06, 5.49455197e+05,
#        4.14066796e+05, 8.30514155e+05, 2.93090530e+05, 6.60856633e+04,
#        2.20644826e+05, 1.23633393e+06, 2.06368059e+06, 8.22674131e+05,
#        1.36634105e+06, 1.05651969e+06, 7.00998795e+05, 5.80550278e+05,
#        2.41890106e+05, 8.17943854e+05, 1.31416993e+06, 4.78347631e+05,
#        5.25187278e+05, 1.11229109e+06, 1.09830771e+06, 3.72080458e+05,
#        4.70260540e+05, 3.80564951e+03, 3.25730044e+05, 1.18820556e+06,
#        1.32352653e+06, 6.11927997e+05, 1.44373631e+06, 1.33006855e+06,
#        1.30095125e+06, 9.24881319e+05, 9.40725411e+05, 1.68027683e+06,
#        5.65221420e+05, 5.21992540e+05, 2.85967808e+05, 1.25240738e+06,
#        8.55341197e+05, 1.43676255e+06, 1.72704229e+06, 1.11280719e+06,
#        2.09129627e+05, 7.26101038e+05, 5.32225255e+04, 1.58214529e+06,
#        1.49941966e+06, 1.06332179e+06, 1.46886078e+06, 1.78676890e+05,
#        5.13993254e+05, 6.94984146e+05, 4.73507967e+05, 3.35704496e+05,
#        1.20901650e+06, 5.36025384e+05, 1.44099962e+06, 1.80938678e+06,
#        1.08668916e+06, 1.02956151e+05, 1.03132926e+06, 6.76109664e+05,
#        7.78780103e+05, 7.37096184e+04, 1.13269333e+06, 1.37725715e+06,
#        1.10140689e+05, 5.34784351e+05, 1.26090216e+06, 1.10263787e+05,
#        1.27183012e+06, 7.13585332e+05, 5.18704760e+05, 5.96881520e+04,
#        5.34694910e+05, 5.00920386e+05, 9.05138782e+04, 1.95491388e+05,
#        1.92201577e+06, 8.53026531e+05, 6.23521483e+05, 2.49675925e+05,
#        9.01348841e+04, 1.03581768e+06, 1.68980183e+06, 5.08497625e+05,
#        1.60447891e+06, 1.94337874e+05, 1.55958596e+06, 5.02939005e+05,
#        3.42780469e+06, 1.62854202e+05, 6.10425612e+05, 7.57473025e+05,
#        8.28803997e+05, 5.96810078e+05, 3.41135290e+05, 1.19961145e+06,
#        1.55602542e+06, 5.85591574e+05, 1.38984346e+06, 3.05500712e+05,
#        1.13503233e+06, 8.61144840e+04, 4.45765785e+05, 4.42921808e+04,
#        3.10924528e+05, 4.50937992e+05, 3.14340864e+05, 3.46013786e+05,
#        1.97976424e+06, 1.24307803e+06, 8.71652747e+05, 5.89435046e+05,
#        1.70889528e+06, 8.62271978e+05, 1.69226329e+06, 1.61343769e+06,
#        1.09061371e+05, 1.34702434e+06, 1.29374143e+06, 3.75845482e+05,
#        9.09956317e+05, 2.57750446e+05, 5.88150103e+05, 1.06316794e+07,
#        1.24603843e+06, 4.72878873e+05, 1.61882474e+05, 4.34269668e+05,
#        1.21069282e+06, 1.16873056e+06, 1.36273985e+06, 7.08991820e+05,
#        9.22287125e+04, 1.04521858e+06, 1.04058778e+06, 3.19402342e+05,
#        1.16824922e+06, 1.75286400e+06, 1.11809435e+06, 3.29784897e+05,
#        9.70299578e+05, 1.20603106e+06, 1.38245756e+05, 7.88951912e+05,
#        5.29437931e+05, 9.91405868e+05, 1.47107480e+06, 9.10843490e+05,
#        8.73643862e+05, 3.12484137e+05, 2.62758822e+05, 1.15796456e+06,
#        2.09206104e+04, 5.50256765e+05, 1.34461746e+05, 1.77890709e+06,
#        1.85993314e+06, 1.07435661e+06, 7.27831373e+05, 8.42605333e+05,
#        7.31017388e+05, 2.75209629e+05, 1.15110152e+06, 9.71872514e+05,
#        8.03711832e+04, 5.09997311e+05, 8.68022043e+05, 7.11949070e+05,
#        1.64481734e+06, 8.47386679e+05, 2.61493404e+05, 9.29206472e+05,
#        6.72025903e+05, 1.16656045e+05, 2.00752637e+05, 1.30324992e+06,
#        3.49236973e+05, 7.66031821e+05, 1.04892185e+06, 9.17019398e+04,
#        5.97876467e+05, 5.78483312e+04, 1.02068114e+06, 5.07742470e+04,
#        1.29271065e+05, 1.63842162e+04, 1.03191328e+06, 1.07614534e+06,
#        8.52193760e+05, 6.87283600e+05, 8.52971605e+05, 1.50183314e+06,
#        6.62497330e+05, 4.62918032e+05, 1.08833931e+06, 2.33297166e+04,
#        7.46084679e+05, 4.66367181e+05, 1.83487689e+06, 7.02315135e+05,
#        9.38351969e+05, 8.46989710e+05, 5.18527514e+05, 7.69650281e+05,
#        1.17494373e+06, 8.96099396e+05, 1.29970068e+06, 9.67760760e+05,
#        1.00783385e+06, 1.18441899e+06, 2.37264268e+05, 1.13572098e+06,
#        1.14108069e+06, 1.31024747e+06, 2.87237450e+06, 1.06844199e+06,
#        1.54326872e+06, 4.17630809e+05, 2.93741230e+05, 7.14627450e+05,
#        2.65391847e+04, 6.26411263e+05, 4.19568851e+04, 1.31102206e+06,
#        4.74107364e+05, 1.24155344e+06, 1.16417420e+06, 3.45874073e+05,
#        9.19517991e+05, 5.34038316e+05, 1.62294705e+06, 6.77268113e+05,
#        1.46591746e+06, 5.22394105e+04, 7.54549848e+05, 7.99167640e+05,
#        1.19911162e+06, 4.23520927e+05, 1.95165442e+06, 7.25590446e+05,
#        4.29264778e+05, 1.40258466e+06, 5.45799406e+05, 9.32295013e+05,
#        6.13300063e+04, 1.28256763e+06, 7.17058063e+05, 1.46565915e+05,
#        1.05046711e+06, 8.93923927e+05, 1.08136200e+06, 2.88241317e+05,
#        1.45829042e+06, 1.52403363e+06, 1.11236809e+06, 3.60806758e+05,
#        5.98541402e+05, 6.68769476e+05, 2.31700054e+05, 1.13401031e+06,
#        3.30514740e+05, 2.42322485e+06, 1.62698395e+06, 1.45048272e+06,
#        1.22409393e+06, 2.23921044e+05, 6.86743000e+05, 2.09240520e+06,
#        3.32628925e+04, 1.13025562e+06, 9.57379454e+05, 5.37364009e+05,
#        6.21144164e+05, 1.24818290e+06, 1.32044667e+05, 1.17567582e+06,
#        1.21273636e+06, 5.22953408e+03, 7.35771562e+05, 1.70876971e+05,
#        4.23888748e+05, 1.44939648e+06, 2.03076674e+06, 1.48174312e+06,
#        1.23092336e+05, 1.81743935e+06, 1.56258644e+05, 4.32587197e+05,
#        1.07889336e+05, 1.61243914e+06, 1.36916422e+06, 9.60448593e+05,
#        6.70970327e+05, 1.12896988e+06, 7.88860890e+05, 6.33251104e+05,
#        1.14740187e+04, 1.36365954e+06, 7.50875495e+05, 9.61223418e+05,
#        1.57934358e+06, 1.57955232e+06])

# %%
knn_index
# Out:
# array([145, 401,  65, 420], dtype=int64)

# %%
dist_total
# Out:
# array([29568.91041199,     0.        ])

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.916083916083916

# %%
# Modelo com código procedural

K = 4
classes = np.unique(y_train)
y_pred = []
vizinhos_index = []
        
for xi in X_test:
    
    euclidistancias = -2 * xi @ X_train.T + (xi**2).sum() + (X_train**2).sum(axis=1)        
    knn_index = np.argsort(euclidistancias)[0:K]
    vizinhos_index.append(knn_index)
    
    contagem = []
    dist_total = []
    
    for classe in classes:
        contagem.append((y_train[knn_index]==classe).sum())
        dist_classe = np.sum(euclidistancias[knn_index][y_train[knn_index]==classe])
        dist_total.append(dist_classe)
    
    contagem = np.array(contagem)
    indice_classes_empatadas = []
    for i in range(len(contagem)):
        if contagem[i] == max(contagem):
            indice_classes_empatadas.append(i)
          
    dist_total = np.array(dist_total)
    
    if len(indice_classes_empatadas) == 1:
        pred_index = np.argmax(contagem)
        y_pred.append(classes[pred_index])
    
    else:
        menor_valor = np.min(dist_total[indice_classes_empatadas])
        indice_menor_dist = np.where(dist_total == menor_valor)[0][0]
        y_pred.append(classes[indice_menor_dist])
                        
y_pred = np.array(y_pred)

# %%
K = 4
classes = np.unique(y_train)
y_pred = []
vizinhos_index = []

# %%
classes
# Out:
# array([0, 1])
